# %%
import numpy as np
import os
# from PIL import Image
import matplotlib.pyplot as plt
import nibabel as nib

# %%
from NIIReader.Augmentation import dataAugmentation

# %% [markdown]
# ## Load Teammate's data and Plot

# %% [markdown]
# ### Processed data
# * each npy file is an array with [# of image, 2, 240, 240], concatenated with [6720, 2, 240,240] size.

# %%
data_path = '/Users/dodo/Documents/projects/maskrcnn/dataset/Processed'

# %%
data = []
for f in os.listdir(data_path):
    data.append(np.load(os.path.join(data_path, f)))

data = np.concatenate(data, axis = 0)
data.shape
# Out:
# (6720, 2, 240, 240)

# %%
# 第一个slice的数据是
data[0].shape
# Out:
# (2, 240, 240)

# %%
# 对于[2, 240, 240] 的数据，第一维[240, 240]是原始图像
plt.imshow(data[0][0], cmap = 'gray')

# %%
# 对于[2, 240, 240] 的数据，第二维[240, 240]是原始图像
plt.imshow(data[0][1], cmap = 'gray')

# %% [markdown]
# ### Explore Original Segmentation data
# * shape: [240, 240, 48]

# %%
seg_data = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/segm.nii.gz').get_fdata()
seg_data.shape
# Out:
# (240, 240, 48)

# %%
plt.imshow(seg_data[:, :, 43])

# %% [markdown]
# ### Read original .nii.gz file

# %% [markdown]
# #### Explore data

# %%
FLAIR = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/orig/FLAIR.nii.gz').get_fdata()
print('Shape', FLAIR.shape)
plt.imshow(FLAIR[:,:,0])
# Out:
# Shape (240, 240, 48)

# %%
reg_IR = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/orig/reg_IR.nii.gz').get_fdata()
print('Shape', reg_IR.shape)
plt.imshow(reg_IR[:,:,0])
# Out:
# Shape (240, 240, 48)

# %%
IR = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/orig/IR.nii.gz').get_fdata()
print('Shape', IR.shape)
# Out:
# Shape (240, 240, 48)

# %%
reg_T1 = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/orig/reg_T1.nii.gz').get_fdata()
print('Shape', reg_T1.shape)
plt.imshow(reg_T1[:, :, 20])
# Out:
# Shape (240, 240, 48)

# %%
mask = nib.load('/Users/dodo/Documents/projects/maskrcnn/dataset/Origin/1/segm.nii.gz').get_fdata()
mask.shape
plt.imshow(mask[:, :, 20])
